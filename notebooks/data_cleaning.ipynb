# %% [markdown]
# ## Data Cleaning Notebook

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient

try:
    #try getting credentials from default credentails
    credentials = DefaultAzureCredential()
    # also Check if given credential can get token successfully.
    if credentials.get_token("https://management.azure.com/.default"):
        print("Token Retrieved")
except Exception as ex:
    #If not found then try getting them using 
    credentials = InteractiveBrowserCredential()
# Out:
# Token Retrieved

# %%
#Authenitcate to use the worksapce with the saved json credentials
ml_client = MLClient.from_config(credential=credentials)
# Out:
# Found the config file in: /config.json

# %% [markdown]
# ## Import the MLTable
